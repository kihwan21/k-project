# %% [markdown]
# ### 1. 필요한 라이브러리 불러오기

# %%
import pandas as pd

# %%
# csv파일 읽기
df = pd.read_csv('국가별_CO2_배출량(1980-2021)_RNN_전처리.csv')

# 출력
df
# Out:
#                           API      COUNTRY  \
# 0    INTL.4008-8-WORL-MMTCD.A        World
# 1    INTL.4002-8-WORL-MMTCD.A        World
# 2    INTL.4010-8-WORL-MMTCD.A        World
# 3    INTL.4006-8-WORL-MMTCD.A        World
# 4     INTL.4008-8-AFG-MMTCD.A  Afghanistan
# ..                        ...          ...
# 915   INTL.4006-8-ZMB-MMTCD.A       Zambia
# 916   INTL.4008-8-ZWE-MMTCD.A     Zimbabwe
# 917   INTL.4002-8-ZWE-MMTCD.A     Zimbabwe
# 918   INTL.4010-8-ZWE-MMTCD.A     Zimbabwe
# 919   INTL.4006-8-ZWE-MMTCD.A     Zimbabwe
#
#                                       EMISSIONS         1980         1981  \
# 0                  CO2 emissions (MMtonnes CO2)  18719.16226  18345.18264
# 1                  Coal and coke (MMtonnes CO2)   7491.61815  7518.337871
# 2           Consumed natural gas (MMtonnes CO2)  2842.337165  2843.874298
# 3    Petroleum and other liquids (MMtonnes CO2)  8385.206946  7982.970473
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 45 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   API        920 non-null    object
#  1   COUNTRY    920 non-null    object
#  2   EMISSIONS  920 non-null    object
#  3   1980       908 non-null    object
#  4   1981       909 non-null    object
#  5   1982       909 non-null    object
#  6   1983       909 non-null    object
#  7   1984       909 non-null    object
#  8   1985       909 non-null    object
#  9   1986       909 non-null    object
#  10  1987       909 non-null    object
#  11  1988       909 non-null    object
#  12  1989       909 non-null    object
#  13  1990       909 non-null    object
#  14  1991       909 non-null    object
#  15  1992       911 non-null    object
#  16  1993       911 non-null    object
#  17  1994       911 non-null    object
#  18  1995       911 non-null    object
# ...

# %%
df = df.drop(columns=['API'])
df
# Out:
#          COUNTRY                                   EMISSIONS         1980  \
# 0          World                CO2 emissions (MMtonnes CO2)  18719.16226
# 1          World                Coal and coke (MMtonnes CO2)   7491.61815
# 2          World         Consumed natural gas (MMtonnes CO2)  2842.337165
# 3          World  Petroleum and other liquids (MMtonnes CO2)  8385.206946
# 4    Afghanistan                CO2 emissions (MMtonnes CO2)  1.325964518
# ..           ...                                         ...          ...
# 915       Zambia  Petroleum and other liquids (MMtonnes CO2)      2.21293
# 916     Zimbabwe                CO2 emissions (MMtonnes CO2)  7.673434383
# 917     Zimbabwe                Coal and coke (MMtonnes CO2)  5.892584383
# 918     Zimbabwe         Consumed natural gas (MMtonnes CO2)            0
# 919     Zimbabwe  Petroleum and other liquids (MMtonnes CO2)      1.78085
#
#             1981         1982         1983         1984         1985  \
# ...

# %%
# melt 함수를 사용하여 열에서 행으로 데이터 변환
df2 = pd.melt(df, id_vars=['COUNTRY', 'EMISSIONS'], var_name='Year', value_name='Value')

# 결과 출력
df2.tail()
# Out:
#         COUNTRY                                   EMISSIONS  Year        Value
# 38635    Zambia  Petroleum and other liquids (MMtonnes CO2)  2021  4.272046215
# 38636  Zimbabwe                CO2 emissions (MMtonnes CO2)  2021  8.118909789
# 38637  Zimbabwe                Coal and coke (MMtonnes CO2)  2021  4.149746663
# 38638  Zimbabwe         Consumed natural gas (MMtonnes CO2)  2021            0
# 38639  Zimbabwe  Petroleum and other liquids (MMtonnes CO2)  2021  3.969163126

# %%
df2.describe()
# Out:
#        COUNTRY                     EMISSIONS   Year  Value
# count    38640                         38640  38640  38232
# unique     230                             4     42  18778
# top      World  CO2 emissions (MMtonnes CO2)   1980      0
# freq       168                          9660    920   9039

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38640 entries, 0 to 38639
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   COUNTRY    38640 non-null  object
#  1   EMISSIONS  38640 non-null  object
#  2   Year       38640 non-null  object
#  3   Value      38232 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
df2.to_csv('국가별_CO2_배출량(1980-2021)_회귀_시각화_전처리.csv')
