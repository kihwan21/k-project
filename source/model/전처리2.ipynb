# %%
import pandas as pd

# %%
co2 = pd.read_csv("탄소배출량_평균_전처리.csv", encoding="euc-kr")

# %%
co2.head()
# Out:
#         일시  이산화탄소(CO2)
# 0  1999-01       373.1
# 1  1999-02       374.0
# 2  1999-03       374.9
# 3  1999-04       375.1
# 4  1999-05       374.0

# %%
co2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   일시          284 non-null    object
#  1   이산화탄소(CO2)  284 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.6+ KB

# %%
# '일시' 열을 datetime 형식으로 변경
co2['일시'] = pd.to_datetime(co2['일시'])

# %%
co2.head()
# Out:
#           일시  이산화탄소(CO2)
# 0 1999-01-01       373.1
# 1 1999-02-01       374.0
# 2 1999-03-01       374.9
# 3 1999-04-01       375.1
# 4 1999-05-01       374.0

# %%
co2
# Out:
#             일시  이산화탄소(CO2)
# 0   1999-01-01  373.100000
# 1   1999-02-01  374.000000
# 2   1999-03-01  374.900000
# 3   1999-04-01  375.100000
# 4   1999-05-01  374.000000
# ..         ...         ...
# 279 2022-04-01  429.083333
# 280 2022-05-01  426.130000
# 281 2022-06-01  422.036667
# 282 2022-07-01  419.610000
# 283 2022-08-01  415.270000
#
# [284 rows x 2 columns]

# %%
# Month 열을 인덱스로 설정
co2.set_index('일시', inplace=True)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt



# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0,1))
df_co2_scaled = scaler.fit_transform(co2)

# 트레이닝셋, 테스트셋 분리
train_size = int(len(df_co2_scaled) * 0.7)
train, test = df_co2_scaled[0:train_size, :], df_co2_scaled[train_size:len(df_co2_scaled), :]

# X, Y 데이터셋 생성
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# LSTM 모델 생성
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# 예측값을 원래의 스케일로 변환
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# RMSE 계산
trainScore = sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

# MAE 계산
trainScore_mae = mean_absolute_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MAE' % (trainScore_mae))
testScore_mae = mean_absolute_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MAE' % (testScore_mae))

# MSE 계산
trainScore_mse = mean_squared_error(trainY[0], trainPredict[:,0])
print('Train Score: %.2f MSE' % (trainScore_mse))
testScore_mse = mean_squared_error(testY[0], testPredict[:,0])
print('Test Score: %.2f MSE' % (testScore_mse))

# 결정계수(R2 Score) 계산
trainScore_r2 = r2_score(trainY[0], trainPredict[:,0])
print('Train Score: %.2f R2' % (trainScore_r2))
testScore_r2 = r2_score(testY[0], testPredict[:,0])
print('Test Score: %.2f R2' % (testScore_r2))

# 2022년 예측
last_val = df_co2_scaled[-1]
last_val_scaled = last_val.reshape(-1, 1)
next_val = model.predict(last_val_scaled)
print("2022년의 CO2 배출량 예측값: ", scaler.inverse_transform(next_val))
# Out:
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# Epoch 1/100
# 196/196 - 2s - loss: 0.1001 - 2s/epoch - 11ms/step
# Epoch 2/100
# 196/196 - 0s - loss: 0.0284 - 414ms/epoch - 2ms/step
# Epoch 3/100
# 196/196 - 1s - loss: 0.0218 - 509ms/epoch - 3ms/step
# Epoch 4/100
# 196/196 - 1s - loss: 0.0187 - 518ms/epoch - 3ms/step
# Epoch 5/100
# 196/196 - 1s - loss: 0.0157 - 549ms/epoch - 3ms/step
# Epoch 6/100
# 196/196 - 1s - loss: 0.0127 - 544ms/epoch - 3ms/step
# Epoch 7/100
# 196/196 - 1s - loss: 0.0102 - 543ms/epoch - 3ms/step
# Epoch 8/100
# 196/196 - 0s - loss: 0.0078 - 478ms/epoch - 2ms/step
# Epoch 9/100
# 196/196 - 1s - loss: 0.0057 - 537ms/epoch - 3ms/step
# Epoch 10/100
# 196/196 - 1s - loss: 0.0042 - 527ms/epoch - 3ms/step
# Epoch 11/100
# 196/196 - 1s - loss: 0.0031 - 523ms/epoch - 3ms/step
# Epoch 12/100
# 196/196 - 1s - loss: 0.0024 - 508ms/epoch - 3ms/step
# Epoch 13/100
# 196/196 - 1s - loss: 0.0020 - 511ms/epoch - 3ms/step
# Epoch 14/100
# 196/196 - 0s - loss: 0.0018 - 443ms/epoch - 2ms/step
# Epoch 15/100
# 196/196 - 1s - loss: 0.0017 - 527ms/epoch - 3ms/step
# Epoch 16/100
# 196/196 - 0s - loss: 0.0016 - 494ms/epoch - 3ms/step
# Epoch 17/100
# 196/196 - 1s - loss: 0.0016 - 523ms/epoch - 3ms/step
# Epoch 18/100
# 196/196 - 1s - loss: 0.0016 - 509ms/epoch - 3ms/step
# Epoch 19/100
# 196/196 - 1s - loss: 0.0016 - 525ms/epoch - 3ms/step
# Epoch 20/100
# 196/196 - 0s - loss: 0.0017 - 456ms/epoch - 2ms/step
# Epoch 21/100
# 196/196 - 1s - loss: 0.0016 - 519ms/epoch - 3ms/step
# Epoch 22/100
# 196/196 - 0s - loss: 0.0017 - 494ms/epoch - 3ms/step
# Epoch 23/100
# 196/196 - 1s - loss: 0.0016 - 520ms/epoch - 3ms/step
# Epoch 24/100
# 196/196 - 1s - loss: 0.0016 - 524ms/epoch - 3ms/step
# Epoch 25/100
# 196/196 - 1s - loss: 0.0016 - 525ms/epoch - 3ms/step
# Epoch 26/100
# 196/196 - 0s - loss: 0.0017 - 495ms/epoch - 3ms/step
# Epoch 27/100
# 196/196 - 1s - loss: 0.0016 - 519ms/epoch - 3ms/step
# Epoch 28/100
# 196/196 - 0s - loss: 0.0017 - 472ms/epoch - 2ms/step
# Epoch 29/100
# 196/196 - 1s - loss: 0.0017 - 535ms/epoch - 3ms/step
# Epoch 30/100
# 196/196 - 1s - loss: 0.0016 - 512ms/epoch - 3ms/step
# Epoch 31/100
# 196/196 - 1s - loss: 0.0016 - 523ms/epoch - 3ms/step
# Epoch 32/100
# 196/196 - 0s - loss: 0.0016 - 472ms/epoch - 2ms/step
# Epoch 33/100
# 196/196 - 1s - loss: 0.0016 - 518ms/epoch - 3ms/step
# Epoch 34/100
# 196/196 - 1s - loss: 0.0016 - 529ms/epoch - 3ms/step
# Epoch 35/100
# 196/196 - 1s - loss: 0.0016 - 531ms/epoch - 3ms/step
# Epoch 36/100
# 196/196 - 0s - loss: 0.0016 - 496ms/epoch - 3ms/step
# Epoch 37/100
# 196/196 - 1s - loss: 0.0017 - 539ms/epoch - 3ms/step
# Epoch 38/100
# 196/196 - 0s - loss: 0.0016 - 455ms/epoch - 2ms/step
# Epoch 39/100
# 196/196 - 1s - loss: 0.0016 - 512ms/epoch - 3ms/step
# Epoch 40/100
# 196/196 - 0s - loss: 0.0016 - 469ms/epoch - 2ms/step
# Epoch 41/100
# 196/196 - 1s - loss: 0.0016 - 515ms/epoch - 3ms/step
# Epoch 42/100
# 196/196 - 0s - loss: 0.0016 - 472ms/epoch - 2ms/step
# Epoch 43/100
# 196/196 - 1s - loss: 0.0016 - 532ms/epoch - 3ms/step
# Epoch 44/100
# 196/196 - 1s - loss: 0.0016 - 520ms/epoch - 3ms/step
# Epoch 45/100
# 196/196 - 1s - loss: 0.0016 - 520ms/epoch - 3ms/step
# Epoch 46/100
# 196/196 - 0s - loss: 0.0016 - 489ms/epoch - 2ms/step
# Epoch 47/100
# 196/196 - 1s - loss: 0.0016 - 518ms/epoch - 3ms/step
# Epoch 48/100
# 196/196 - 0s - loss: 0.0016 - 487ms/epoch - 2ms/step
# Epoch 49/100
# 196/196 - 0s - loss: 0.0016 - 479ms/epoch - 2ms/step
# Epoch 50/100
# 196/196 - 1s - loss: 0.0016 - 521ms/epoch - 3ms/step
# Epoch 51/100
# 196/196 - 1s - loss: 0.0016 - 533ms/epoch - 3ms/step
# Epoch 52/100
# 196/196 - 1s - loss: 0.0016 - 516ms/epoch - 3ms/step
# Epoch 53/100
# 196/196 - 1s - loss: 0.0016 - 531ms/epoch - 3ms/step
# Epoch 54/100
# 196/196 - 0s - loss: 0.0016 - 496ms/epoch - 3ms/step
# Epoch 55/100
# 196/196 - 1s - loss: 0.0016 - 527ms/epoch - 3ms/step
# Epoch 56/100
# 196/196 - 1s - loss: 0.0016 - 508ms/epoch - 3ms/step
# Epoch 57/100
# 196/196 - 1s - loss: 0.0016 - 523ms/epoch - 3ms/step
# Epoch 58/100
# 196/196 - 1s - loss: 0.0016 - 527ms/epoch - 3ms/step
# Epoch 59/100
# 196/196 - 1s - loss: 0.0016 - 525ms/epoch - 3ms/step
# Epoch 60/100
# 196/196 - 1s - loss: 0.0016 - 520ms/epoch - 3ms/step
# Epoch 61/100
# 196/196 - 1s - loss: 0.0016 - 539ms/epoch - 3ms/step
# Epoch 62/100
# 196/196 - 0s - loss: 0.0016 - 457ms/epoch - 2ms/step
# Epoch 63/100
# 196/196 - 1s - loss: 0.0016 - 560ms/epoch - 3ms/step
# Epoch 64/100
# 196/196 - 1s - loss: 0.0016 - 624ms/epoch - 3ms/step
# Epoch 65/100
# 196/196 - 1s - loss: 0.0016 - 618ms/epoch - 3ms/step
# Epoch 66/100
# 196/196 - 1s - loss: 0.0016 - 590ms/epoch - 3ms/step
# Epoch 67/100
# 196/196 - 1s - loss: 0.0016 - 617ms/epoch - 3ms/step
# Epoch 68/100
# 196/196 - 1s - loss: 0.0016 - 549ms/epoch - 3ms/step
# Epoch 69/100
# 196/196 - 1s - loss: 0.0016 - 514ms/epoch - 3ms/step
# Epoch 70/100
# 196/196 - 1s - loss: 0.0016 - 529ms/epoch - 3ms/step
# Epoch 71/100
# 196/196 - 1s - loss: 0.0016 - 516ms/epoch - 3ms/step
# Epoch 72/100
# 196/196 - 1s - loss: 0.0017 - 512ms/epoch - 3ms/step
# Epoch 73/100
# 196/196 - 1s - loss: 0.0016 - 514ms/epoch - 3ms/step
# Epoch 74/100
# 196/196 - 1s - loss: 0.0016 - 517ms/epoch - 3ms/step
# Epoch 75/100
# 196/196 - 1s - loss: 0.0016 - 521ms/epoch - 3ms/step
# Epoch 76/100
# 196/196 - 0s - loss: 0.0016 - 500ms/epoch - 3ms/step
# Epoch 77/100
# 196/196 - 0s - loss: 0.0016 - 458ms/epoch - 2ms/step
# Epoch 78/100
# 196/196 - 1s - loss: 0.0016 - 515ms/epoch - 3ms/step
# Epoch 79/100
# 196/196 - 1s - loss: 0.0016 - 520ms/epoch - 3ms/step
# Epoch 80/100
# 196/196 - 1s - loss: 0.0016 - 513ms/epoch - 3ms/step
# Epoch 81/100
# 196/196 - 1s - loss: 0.0016 - 509ms/epoch - 3ms/step
# Epoch 82/100
# 196/196 - 1s - loss: 0.0016 - 521ms/epoch - 3ms/step
# Epoch 83/100
# 196/196 - 1s - loss: 0.0016 - 533ms/epoch - 3ms/step
# Epoch 84/100
# 196/196 - 1s - loss: 0.0016 - 529ms/epoch - 3ms/step
# Epoch 85/100
# 196/196 - 1s - loss: 0.0017 - 514ms/epoch - 3ms/step
# Epoch 86/100
# 196/196 - 0s - loss: 0.0016 - 477ms/epoch - 2ms/step
# Epoch 87/100
# 196/196 - 1s - loss: 0.0016 - 519ms/epoch - 3ms/step
# Epoch 88/100
# 196/196 - 1s - loss: 0.0016 - 515ms/epoch - 3ms/step
# Epoch 89/100
# 196/196 - 1s - loss: 0.0016 - 505ms/epoch - 3ms/step
# Epoch 90/100
# 196/196 - 1s - loss: 0.0016 - 504ms/epoch - 3ms/step
# Epoch 91/100
# 196/196 - 1s - loss: 0.0016 - 516ms/epoch - 3ms/step
# Epoch 92/100
# 196/196 - 1s - loss: 0.0017 - 536ms/epoch - 3ms/step
# Epoch 93/100
# 196/196 - 1s - loss: 0.0016 - 534ms/epoch - 3ms/step
# Epoch 94/100
# 196/196 - 1s - loss: 0.0016 - 527ms/epoch - 3ms/step
# Epoch 95/100
# 196/196 - 1s - loss: 0.0016 - 564ms/epoch - 3ms/step
# Epoch 96/100
# 196/196 - 1s - loss: 0.0016 - 523ms/epoch - 3ms/step
# Epoch 97/100
# 196/196 - 0s - loss: 0.0016 - 491ms/epoch - 3ms/step
# Epoch 98/100
# 196/196 - 0s - loss: 0.0016 - 480ms/epoch - 2ms/step
# Epoch 99/100
# 196/196 - 0s - loss: 0.0017 - 476ms/epoch - 2ms/step
# Epoch 100/100
# 196/196 - 0s - loss: 0.0016 - 466ms/epoch - 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# Train Score: 2.57 RMSE
# Test Score: 2.60 RMSE
# Train Score: 2.00 MAE
# Test Score: 2.08 MAE
# Train Score: 6.60 MSE
# Test Score: 6.77 MSE
# Train Score: 0.95 R2
# Test Score: 0.85 R2
# 1/1 [==============================] - 0s 25ms/step
# 2022년의 CO2 배출량 예측값:  [[415.69385]]

# %%
df = pd.read_csv("에너지 생산 소비 병합_전처리7.csv", encoding="euc-kr")

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split


# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0,1))

# 'CO2 emissions (MMtonnes CO2)' 열을 제거한 후 스케일링
df_combined2 = df.drop('CO2 emissions (MMtonnes CO2)', axis=1)
df_combined_scaled2 = scaler.fit_transform(df_combined2)

# 목표 변수에 대해서만 스케일링
y = df['CO2 emissions (MMtonnes CO2)']
y = scaler.fit_transform(y.values.reshape(-1, 1))

X = df_combined_scaled2

# train_test_split() 함수로 학습 데이터와 테스트 데이터 분리하기
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1, shuffle = False)

# RandomForestRegressor 모델 생성/학습
model_RF = RandomForestRegressor()
model_RF.fit(X_train, y_train.ravel())  # ravel()로 1차원 배열로 전환

# Predict를 수행하고 mean_absolute_error와 rmse 결과 출력하기
pred = model_RF.predict(X_test)
print(mean_absolute_error(y_test, pred))
print(sqrt(mean_squared_error(y_test, pred)))
r2 = r2_score(y_test, pred)
print(f"R-squared: {r2}")
