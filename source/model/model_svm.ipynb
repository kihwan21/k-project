# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/k-project/raw_datasets/최종(진짜)/01_최종_국내_데이터(x,y 합친 데이터셋).csv', encoding="euc-kr")

df.head()
# Out:
#            일시  합계 생산(1000 toe)  무연탄 생산(1000 toe)  천연가스 생산(1000 toe)  \
# 0  1999-01-01           2303.0             162.0                0.0
# 1  1999-02-01           2216.0             137.0                0.0
# 2  1999-03-01           2444.0             174.0                0.0
# 3  1999-04-01           2342.0             163.0                0.0
# 4  1999-05-01           2601.0             151.0                0.0
#
#    수력 생산(1000 toe)  원자력 생산(1000 toe)  신재생 및 기타 생산(1000 toe)  합계 소비(1000 toe)  \
# 0             78.0            1928.0                  137.0          13466.0
# 1             94.0            1854.0                  132.0          12179.0
# 2            112.0            2012.0                  146.0          13219.0
# 3            137.0            1889.0                  152.0          11957.0
# 4            131.0            2163.0                  156.0          10270.0
#
#    석탄 소비(1000 toe)  석유 소비(1000 toe)  액화천연가스 소비(1000 toe)  도시가스 소비(1000 toe)  \
# ...

# %%
df['일시'].values
# Out:
# array(['1999-01-01', '1999-02-01', '1999-03-01', '1999-04-01',
#        '1999-05-01', '1999-06-01', '1999-07-01', '1999-08-01',
#        '1999-09-01', '1999-10-01', '1999-11-01', '1999-12-01',
#        '2000-01-01', '2000-02-01', '2000-03-01', '2000-04-01',
#        '2000-05-01', '2000-06-01', '2000-07-01', '2000-08-01',
#        '2000-09-01', '2000-10-01', '2000-11-01', '2000-12-01',
#        '2001-01-01', '2001-02-01', '2001-03-01', '2001-04-01',
#        '2001-05-01', '2001-06-01', '2001-07-01', '2001-08-01',
#        '2001-09-01', '2001-10-01', '2001-11-01', '2001-12-01',
#        '2002-01-01', '2002-02-01', '2002-03-01', '2002-04-01',
#        '2002-05-01', '2002-06-01', '2002-07-01', '2002-08-01',
#        '2002-09-01', '2002-10-01', '2002-11-01', '2002-12-01',
#        '2003-01-01', '2003-02-01', '2003-03-01', '2003-04-01',
#        '2003-05-01', '2003-06-01', '2003-07-01', '2003-08-01',
#        '2003-09-01', '2003-10-01', '2003-11-01', '2003-12-01',
# ...

# %%
# '날짜' 열을 datetime으로 변환
df['일시'] = pd.to_datetime(df['일시'])

df['일시'].values
# Out:
# array(['1999-01-01T00:00:00.000000000', '1999-02-01T00:00:00.000000000',
#        '1999-03-01T00:00:00.000000000', '1999-04-01T00:00:00.000000000',
#        '1999-05-01T00:00:00.000000000', '1999-06-01T00:00:00.000000000',
#        '1999-07-01T00:00:00.000000000', '1999-08-01T00:00:00.000000000',
#        '1999-09-01T00:00:00.000000000', '1999-10-01T00:00:00.000000000',
#        '1999-11-01T00:00:00.000000000', '1999-12-01T00:00:00.000000000',
#        '2000-01-01T00:00:00.000000000', '2000-02-01T00:00:00.000000000',
#        '2000-03-01T00:00:00.000000000', '2000-04-01T00:00:00.000000000',
#        '2000-05-01T00:00:00.000000000', '2000-06-01T00:00:00.000000000',
#        '2000-07-01T00:00:00.000000000', '2000-08-01T00:00:00.000000000',
#        '2000-09-01T00:00:00.000000000', '2000-10-01T00:00:00.000000000',
#        '2000-11-01T00:00:00.000000000', '2000-12-01T00:00:00.000000000',
#        '2001-01-01T00:00:00.000000000', '2001-02-01T00:00:00.000000000',
# ...

# %%
# # datetime을 float로 변환 (timestamp로 변환)
# df['일시'] = df['일시'].apply(lambda x: x.timestamp())

# %%
# df['일시'].values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   일시                     284 non-null    datetime64[ns]
#  1   합계 생산(1000 toe)        284 non-null    float64
#  2   무연탄 생산(1000 toe)       284 non-null    float64
#  3   천연가스 생산(1000 toe)      284 non-null    float64
#  4   수력 생산(1000 toe)        284 non-null    float64
#  5   원자력 생산(1000 toe)       284 non-null    float64
#  6   신재생 및 기타 생산(1000 toe)  284 non-null    float64
#  7   합계 소비(1000 toe)        284 non-null    float64
#  8   석탄 소비(1000 toe)        284 non-null    float64
#  9   석유 소비(1000 toe)        284 non-null    float64
#  10  액화천연가스 소비(1000 toe)    284 non-null    float64
#  11  도시가스 소비(1000 toe)      284 non-null    float64
#  12  전력 소비(1000 toe)        284 non-null    float64
#  13  열 소비(1000 toe)         284 non-null    float64
# ...

# %%
# '날짜' 열에서 '년도'와 '월' 정보 추출하여 새로운 열로 추가
df['년도'] = df['일시'].dt.year
df['월'] = df['일시'].dt.month

# %%
df['일시']
# Out:
# 0     1999-01-01
# 1     1999-02-01
# 2     1999-03-01
# 3     1999-04-01
# 4     1999-05-01
#          ...
# 279   2022-04-01
# 280   2022-05-01
# 281   2022-06-01
# 282   2022-07-01
# 283   2022-08-01
# Name: 일시, Length: 284, dtype: datetime64[ns]

# %%
df.columns
# Out:
# Index(['일시', '합계 생산(1000 toe)', '무연탄 생산(1000 toe)', '천연가스 생산(1000 toe)',
#        '수력 생산(1000 toe)', '원자력 생산(1000 toe)', '신재생 및 기타 생산(1000 toe)',
#        '합계 소비(1000 toe)', '석탄 소비(1000 toe)', '석유 소비(1000 toe)',
#        '액화천연가스 소비(1000 toe)', '도시가스 소비(1000 toe)', '전력 소비(1000 toe)',
#        '열 소비(1000 toe)', '신재생 및 기타 소비(%)', '이산화탄소(CO2)', '년도', '월'],
#       dtype='object')

# %%
#학습데이터 X, y
X = df.drop(['이산화탄소(CO2)','일시'], axis=1) 
y = df['이산화탄소(CO2)']

# %%
X
# Out:
#      합계 생산(1000 toe)  무연탄 생산(1000 toe)  천연가스 생산(1000 toe)  수력 생산(1000 toe)  \
# 0             2303.0             162.0                0.0             78.0
# 1             2216.0             137.0                0.0             94.0
# 2             2444.0             174.0                0.0            112.0
# 3             2342.0             163.0                0.0            137.0
# 4             2601.0             151.0                0.0            131.0
# ..               ...               ...                ...              ...
# 279           4952.0              36.0                0.0            101.0
# 280           5339.0              34.0                0.0            115.0
# 281           5103.0              34.0                0.0            118.0
# 282           5402.0              32.0                0.0            146.0
# 283           5685.0              29.0                0.0            218.0
#
#      원자력 생산(1000 toe)  신재생 및 기타 생산(1000 toe)  합계 소비(1000 toe)  \
# ...

# %%
print(X.shape)
print(y.shape)
# Out:
# (284, 16)
# (284,)

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

print('입력변수(학습데이터): ',  X_train.shape)
print('입력변수(검증데이터): ', X_test.shape)
print('종속변수(학습데이터): ',  y_train.shape)
print('종속변수(검증데이터): ', y_test.shape)
# Out:
# 입력변수(학습데이터):  (227, 16)
# 입력변수(검증데이터):  (57, 16)
# 종속변수(학습데이터):  (227,)
# 종속변수(검증데이터):  (57,)

# %%
# 선형 SVM 모델 생성
model = svm.SVC()
model.fit(X_train, y_train)

# 테스트 데이터로 예측
y_pred = model.predict(X_test)

# 정확도 평가
accuracy = accuracy_score(y_test, y_pred)
print(f"정확도: {accuracy}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\k-project\source\model\model_svm.ipynb Cell 16 line 3
#       <a href='vscode-notebook-cell:/c%3A/k-project/source/model/model_svm.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> # 선형 SVM 모델 생성
#       <a href='vscode-notebook-cell:/c%3A/k-project/source/model/model_svm.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> model = svm.SVC()
# ----> <a href='vscode-notebook-cell:/c%3A/k-project/source/model/model_svm.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> model.fit(X_train, y_train)
#       <a href='vscode-notebook-cell:/c%3A/k-project/source/model/model_svm.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> # 테스트 데이터로 예측
#       <a href='vscode-notebook-cell:/c%3A/k-project/source/model/model_svm.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> y_pred = model.predict(X_test)
#
# ...
