# %%
'''
다 함께 하는 작업 공간이기 때문에 경로나 파일 명 등을 통일 해야 할 것 같습니다.
그렇게 하지 않으면 경로 때문에 매번 새로운 커밋이 생성 됩니다.
'''

import os

# 현재 작업 디렉토리 확인
current_directory = os.getcwd()
print("Current directory:", current_directory)

# 필요한 CSV 파일이 있는 디렉토리로 변경
target_directory = "C:/k-project/raw_datasets/최종" # 해당 코드 부분의 경로를 동일하게 하거나 / 깃 리파지토리 안에 파일을 집어 넣는 작업 필요.      
os.chdir(target_directory)

import pandas as pd

# CSV 파일 불러오기
csv_filename = "최종_수정02_국가별_시계열_데이터_전처리(인구+GDP).csv"  # CSV 파일명. 파일명을 모두 동일하게 해야합니다.
df = pd.read_csv(csv_filename)

# 데이터 확인
print(df.head())
# Out:
# Current directory: c:\k-project\source\model
#      COUNTRY                 Composite_Indicators        1980        1981  \
# 0  Australia      Biomass and waste (billion kWh)    0.400000    0.400000
# 1  Australia         CO2 emissions (MMtonnes CO2)  221.314466  223.053852
# 2  Australia                      Coal (quad Btu)    1.287102    1.317761
# 3  Australia         Coal and coke (MMtonnes CO2)  126.716798  129.723177
# 4  Australia  Consumed natural gas (MMtonnes CO2)   17.989712   20.559671
#
#          1982        1983        1984        1985        1986        1987  \
# 0    0.500000    0.400000    0.400000    0.400000    0.400000    0.400000
# 1  230.129715  219.685227  227.994782  240.581272  241.444382  259.333455
# 2    1.394639    1.325105    1.267020    1.362507    1.354289    1.488758
# 3  133.863175  125.379483  120.132560  129.281043  127.917222  140.745976
# 4   22.738549   23.073761   24.605560   26.309368   28.718725   29.439871
#
#    ...        2012        2013        2014        2015        2016  \
# 0  ...    3.043000    3.152000    3.511000    3.608000    3.722000
# 1  ...  393.234943  385.146233  377.521170  384.191753  395.971861
# 2  ...    1.944928    1.818970    1.726155    1.777427    1.851000
# 3  ...  173.910304  161.363707  152.786961  157.999239  163.960594
# 4  ...   71.402493   73.610853   75.233517   76.261073   82.848989
#
#          2017        2018        2019        2020        2021
# 0    3.501000    3.518000    3.496000    3.352000    2.784000
# 1  406.642388  411.530154  406.113146  372.647180  377.152725
# 2    1.834908    1.750055    1.696931    1.602948    1.670752
# 3  162.853470  165.699363  160.967880  151.627761  157.961453
# 4   86.614156   85.951616   87.757573   86.105841   81.757000
#
# [5 rows x 44 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
df
# Out:
#        COUNTRY                        Composite_Indicators        1980  \
# 0    Australia             Biomass and waste (billion kWh)    0.400000
# 1    Australia                CO2 emissions (MMtonnes CO2)  221.314466
# 2    Australia                             Coal (quad Btu)    1.287102
# 3    Australia                Coal and coke (MMtonnes CO2)  126.716798
# 4    Australia         Consumed natural gas (MMtonnes CO2)   17.989712
# ..         ...                                         ...         ...
# 437      World             Renewables and other (quad Btu)   20.704043
# 438      World                         Solar (billion kWh)    0.000000
# 439      World  Solar, tide, wave, fuel cell (billion kWh)    0.470000
# 440      World                 Tide and wave (billion kWh)    0.470000
# 441      World                          Wind (billion kWh)    0.011000
#
#            1981        1982        1983        1984        1985        1986  \
# 0      0.400000    0.500000    0.400000    0.400000    0.400000    0.400000
# 1    223.053852  230.129715  219.685227  227.994782  240.581272  241.444382
# 2      1.317761    1.394639    1.325105    1.267020    1.362507    1.354289
# 3    129.723177  133.863175  125.379483  120.132560  129.281043  127.917222
# 4     20.559671   22.738549   23.073761   24.605560   26.309368   28.718725
# ..          ...         ...         ...         ...         ...         ...
# 437   21.118496   21.727660   22.952488   23.548531   23.807988   24.234789
# 438    0.000000    0.000000    0.000050    0.006298    0.011680    0.016132
# 439    0.530000    0.570000    0.570050    0.584298    0.604680    0.609132
# 440    0.530000    0.570000    0.570000    0.578000    0.593000    0.593000
# 441    0.011000    0.019000    0.032668    0.044490    0.063762    0.140189
#
#            1987  ...        2012        2013        2014        2015  \
# 0      0.400000  ...    3.043000    3.152000    3.511000    3.608000
# 1    259.333455  ...  393.234943  385.146233  377.521170  384.191753
# 2      1.488758  ...    1.944928    1.818970    1.726155    1.777427
# 3    140.745976  ...  173.910304  161.363707  152.786961  157.999239
# 4     29.439871  ...   71.402493   73.610853   75.233517   76.261073
# ..          ...  ...         ...         ...         ...         ...
# 437   24.129132  ...   48.871858   52.501922   54.777703   55.743526
# 438    0.011597  ...  104.215592  146.678326  202.219806  260.178522
# 439    0.585597  ...  105.177593  147.604326  203.218806  261.184522
# 440    0.574000  ...    0.962000    0.926000    0.999000    1.006000
# 441    0.198541  ...  521.502832  645.078310  717.250171  827.434723
#
#            2016         2017         2018         2019         2020  \
# 0      3.722000     3.501000     3.518000     3.496000     3.352000
# 1    395.971861   406.642388   411.530154   406.113146   372.647180
# 2      1.851000     1.834908     1.750055     1.696931     1.602948
# 3    163.960594   162.853470   165.699363   160.967880   151.627761
# 4     82.848989    86.614156    85.951616    87.757573    86.105841
# ..          ...          ...          ...          ...          ...
# 437   58.857046    62.031526    65.295120    66.916580    69.793520
# 438  341.478488   445.050819   569.837749   701.027151   849.135469
# 439  342.505588   446.082819   570.842749   702.027151   850.124470
# 440    1.027100     1.032000     1.005000     1.000000     0.989000
# 441  957.251181  1127.113911  1263.515951  1399.096941  1590.472512
#
#             2021
# 0       2.784000
# 1     377.152725
# 2       1.670752
# 3     157.961453
# 4      81.757000
# ..           ...
# 437    72.842014
# 438  1036.244409
# 439  1037.218409
# 440     0.974000
# 441  1807.798762
#
# [442 rows x 44 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# co2배출량과 호주 데이터만 선택
df_co2 = df[(df['Composite_Indicators'] == 'CO2 emissions (MMtonnes CO2)') & (df['COUNTRY'] == 'Australia')]

# 'Composite_Indicators'와 'COUNTRY' 컬럼을 삭제하고, 데이터프레임을 전치(transpose)
# 전치 작업으로 인해, 각 연도가 행으로, CO2 배출량이 열로 배치
df_co2 = df_co2.drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_co2.columns = ['CO2_emissions']

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0,1))
df_co2_scaled = scaler.fit_transform(df_co2)

# 트레이닝셋, 테스트셋 분리
train_size = int(len(df_co2_scaled) * 0.7)
train, test = df_co2_scaled[0:train_size, :], df_co2_scaled[train_size:len(df_co2_scaled), :]

# X, Y 데이터셋 생성
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# LSTM 모델 생성
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# 2022년 예측
last_val = df_co2_scaled[-1]
last_val_scaled = last_val.reshape(-1, 1)
next_val = model.predict(last_val_scaled)
print("2022년의 CO2 배출량 예측값: ", scaler.inverse_transform(next_val))
# Out:
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# Epoch 1/100
# 27/27 - 2s - loss: 0.2847 - 2s/epoch - 57ms/step
# Epoch 2/100
# 27/27 - 0s - loss: 0.2407 - 77ms/epoch - 3ms/step
# Epoch 3/100
# 27/27 - 0s - loss: 0.2033 - 73ms/epoch - 3ms/step
# Epoch 4/100
# 27/27 - 0s - loss: 0.1712 - 79ms/epoch - 3ms/step
# Epoch 5/100
# 27/27 - 0s - loss: 0.1453 - 78ms/epoch - 3ms/step
# Epoch 6/100
# 27/27 - 0s - loss: 0.1231 - 81ms/epoch - 3ms/step
# Epoch 7/100
# 27/27 - 0s - loss: 0.1067 - 81ms/epoch - 3ms/step
# Epoch 8/100
# 27/27 - 0s - loss: 0.0915 - 81ms/epoch - 3ms/step
# Epoch 9/100
# 27/27 - 0s - loss: 0.0804 - 82ms/epoch - 3ms/step
# Epoch 10/100
# 27/27 - 0s - loss: 0.0725 - 84ms/epoch - 3ms/step
# Epoch 11/100
# 27/27 - 0s - loss: 0.0664 - 83ms/epoch - 3ms/step
# Epoch 12/100
# 27/27 - 0s - loss: 0.0613 - 79ms/epoch - 3ms/step
# Epoch 13/100
# 27/27 - 0s - loss: 0.0574 - 81ms/epoch - 3ms/step
# Epoch 14/100
# 27/27 - 0s - loss: 0.0544 - 83ms/epoch - 3ms/step
# Epoch 15/100
# 27/27 - 0s - loss: 0.0520 - 74ms/epoch - 3ms/step
# Epoch 16/100
# 27/27 - 0s - loss: 0.0500 - 77ms/epoch - 3ms/step
# Epoch 17/100
# 27/27 - 0s - loss: 0.0482 - 79ms/epoch - 3ms/step
# Epoch 18/100
# 27/27 - 0s - loss: 0.0465 - 77ms/epoch - 3ms/step
# Epoch 19/100
# 27/27 - 0s - loss: 0.0450 - 79ms/epoch - 3ms/step
# Epoch 20/100
# 27/27 - 0s - loss: 0.0434 - 88ms/epoch - 3ms/step
# Epoch 21/100
# 27/27 - 0s - loss: 0.0420 - 74ms/epoch - 3ms/step
# Epoch 22/100
# 27/27 - 0s - loss: 0.0405 - 83ms/epoch - 3ms/step
# Epoch 23/100
# 27/27 - 0s - loss: 0.0391 - 77ms/epoch - 3ms/step
# Epoch 24/100
# 27/27 - 0s - loss: 0.0378 - 76ms/epoch - 3ms/step
# Epoch 25/100
# 27/27 - 0s - loss: 0.0362 - 81ms/epoch - 3ms/step
# Epoch 26/100
# 27/27 - 0s - loss: 0.0350 - 75ms/epoch - 3ms/step
# Epoch 27/100
# 27/27 - 0s - loss: 0.0335 - 78ms/epoch - 3ms/step
# Epoch 28/100
# 27/27 - 0s - loss: 0.0323 - 84ms/epoch - 3ms/step
# Epoch 29/100
# 27/27 - 0s - loss: 0.0312 - 81ms/epoch - 3ms/step
# Epoch 30/100
# 27/27 - 0s - loss: 0.0297 - 76ms/epoch - 3ms/step
# Epoch 31/100
# 27/27 - 0s - loss: 0.0287 - 75ms/epoch - 3ms/step
# Epoch 32/100
# 27/27 - 0s - loss: 0.0271 - 86ms/epoch - 3ms/step
# Epoch 33/100
# 27/27 - 0s - loss: 0.0259 - 73ms/epoch - 3ms/step
# Epoch 34/100
# 27/27 - 0s - loss: 0.0247 - 75ms/epoch - 3ms/step
# Epoch 35/100
# 27/27 - 0s - loss: 0.0240 - 80ms/epoch - 3ms/step
# Epoch 36/100
# 27/27 - 0s - loss: 0.0226 - 79ms/epoch - 3ms/step
# Epoch 37/100
# 27/27 - 0s - loss: 0.0213 - 77ms/epoch - 3ms/step
# Epoch 38/100
# 27/27 - 0s - loss: 0.0203 - 69ms/epoch - 3ms/step
# Epoch 39/100
# 27/27 - 0s - loss: 0.0192 - 76ms/epoch - 3ms/step
# Epoch 40/100
# 27/27 - 0s - loss: 0.0182 - 79ms/epoch - 3ms/step
# Epoch 41/100
# 27/27 - 0s - loss: 0.0173 - 77ms/epoch - 3ms/step
# Epoch 42/100
# 27/27 - 0s - loss: 0.0163 - 80ms/epoch - 3ms/step
# Epoch 43/100
# 27/27 - 0s - loss: 0.0155 - 75ms/epoch - 3ms/step
# Epoch 44/100
# 27/27 - 0s - loss: 0.0145 - 75ms/epoch - 3ms/step
# Epoch 45/100
# 27/27 - 0s - loss: 0.0137 - 78ms/epoch - 3ms/step
# Epoch 46/100
# 27/27 - 0s - loss: 0.0129 - 77ms/epoch - 3ms/step
# Epoch 47/100
# 27/27 - 0s - loss: 0.0120 - 76ms/epoch - 3ms/step
# Epoch 48/100
# 27/27 - 0s - loss: 0.0113 - 81ms/epoch - 3ms/step
# Epoch 49/100
# 27/27 - 0s - loss: 0.0106 - 78ms/epoch - 3ms/step
# Epoch 50/100
# 27/27 - 0s - loss: 0.0100 - 78ms/epoch - 3ms/step
# Epoch 51/100
# 27/27 - 0s - loss: 0.0093 - 97ms/epoch - 4ms/step
# Epoch 52/100
# 27/27 - 0s - loss: 0.0087 - 78ms/epoch - 3ms/step
# Epoch 53/100
# 27/27 - 0s - loss: 0.0082 - 81ms/epoch - 3ms/step
# Epoch 54/100
# 27/27 - 0s - loss: 0.0077 - 80ms/epoch - 3ms/step
# Epoch 55/100
# 27/27 - 0s - loss: 0.0070 - 75ms/epoch - 3ms/step
# Epoch 56/100
# 27/27 - 0s - loss: 0.0066 - 76ms/epoch - 3ms/step
# Epoch 57/100
# 27/27 - 0s - loss: 0.0061 - 77ms/epoch - 3ms/step
# Epoch 58/100
# 27/27 - 0s - loss: 0.0057 - 72ms/epoch - 3ms/step
# Epoch 59/100
# 27/27 - 0s - loss: 0.0053 - 76ms/epoch - 3ms/step
# Epoch 60/100
# 27/27 - 0s - loss: 0.0049 - 79ms/epoch - 3ms/step
# Epoch 61/100
# 27/27 - 0s - loss: 0.0047 - 76ms/epoch - 3ms/step
# Epoch 62/100
# 27/27 - 0s - loss: 0.0043 - 78ms/epoch - 3ms/step
# Epoch 63/100
# 27/27 - 0s - loss: 0.0040 - 78ms/epoch - 3ms/step
# Epoch 64/100
# 27/27 - 0s - loss: 0.0037 - 83ms/epoch - 3ms/step
# Epoch 65/100
# 27/27 - 0s - loss: 0.0035 - 81ms/epoch - 3ms/step
# Epoch 66/100
# 27/27 - 0s - loss: 0.0033 - 79ms/epoch - 3ms/step
# Epoch 67/100
# 27/27 - 0s - loss: 0.0031 - 81ms/epoch - 3ms/step
# Epoch 68/100
# 27/27 - 0s - loss: 0.0029 - 80ms/epoch - 3ms/step
# Epoch 69/100
# 27/27 - 0s - loss: 0.0028 - 75ms/epoch - 3ms/step
# Epoch 70/100
# 27/27 - 0s - loss: 0.0026 - 75ms/epoch - 3ms/step
# Epoch 71/100
# 27/27 - 0s - loss: 0.0025 - 76ms/epoch - 3ms/step
# Epoch 72/100
# 27/27 - 0s - loss: 0.0024 - 77ms/epoch - 3ms/step
# Epoch 73/100
# 27/27 - 0s - loss: 0.0023 - 75ms/epoch - 3ms/step
# Epoch 74/100
# 27/27 - 0s - loss: 0.0021 - 76ms/epoch - 3ms/step
# Epoch 75/100
# 27/27 - 0s - loss: 0.0021 - 75ms/epoch - 3ms/step
# Epoch 76/100
# 27/27 - 0s - loss: 0.0020 - 75ms/epoch - 3ms/step
# Epoch 77/100
# 27/27 - 0s - loss: 0.0020 - 76ms/epoch - 3ms/step
# Epoch 78/100
# 27/27 - 0s - loss: 0.0019 - 76ms/epoch - 3ms/step
# Epoch 79/100
# 27/27 - 0s - loss: 0.0019 - 78ms/epoch - 3ms/step
# Epoch 80/100
# 27/27 - 0s - loss: 0.0018 - 77ms/epoch - 3ms/step
# Epoch 81/100
# 27/27 - 0s - loss: 0.0018 - 74ms/epoch - 3ms/step
# Epoch 82/100
# 27/27 - 0s - loss: 0.0018 - 78ms/epoch - 3ms/step
# Epoch 83/100
# 27/27 - 0s - loss: 0.0017 - 78ms/epoch - 3ms/step
# Epoch 84/100
# 27/27 - 0s - loss: 0.0017 - 78ms/epoch - 3ms/step
# Epoch 85/100
# 27/27 - 0s - loss: 0.0017 - 83ms/epoch - 3ms/step
# Epoch 86/100
# 27/27 - 0s - loss: 0.0017 - 73ms/epoch - 3ms/step
# Epoch 87/100
# 27/27 - 0s - loss: 0.0017 - 77ms/epoch - 3ms/step
# Epoch 88/100
# 27/27 - 0s - loss: 0.0016 - 80ms/epoch - 3ms/step
# Epoch 89/100
# 27/27 - 0s - loss: 0.0016 - 76ms/epoch - 3ms/step
# Epoch 90/100
# 27/27 - 0s - loss: 0.0017 - 77ms/epoch - 3ms/step
# Epoch 91/100
# 27/27 - 0s - loss: 0.0017 - 78ms/epoch - 3ms/step
# Epoch 92/100
# 27/27 - 0s - loss: 0.0016 - 78ms/epoch - 3ms/step
# Epoch 93/100
# 27/27 - 0s - loss: 0.0016 - 78ms/epoch - 3ms/step
# Epoch 94/100
# 27/27 - 0s - loss: 0.0016 - 73ms/epoch - 3ms/step
# Epoch 95/100
# 27/27 - 0s - loss: 0.0016 - 78ms/epoch - 3ms/step
# Epoch 96/100
# 27/27 - 0s - loss: 0.0016 - 78ms/epoch - 3ms/step
# Epoch 97/100
# 27/27 - 0s - loss: 0.0016 - 72ms/epoch - 3ms/step
# Epoch 98/100
# 27/27 - 0s - loss: 0.0016 - 74ms/epoch - 3ms/step
# Epoch 99/100
# 27/27 - 0s - loss: 0.0016 - 72ms/epoch - 3ms/step
# Epoch 100/100
# 27/27 - 0s - loss: 0.0016 - 78ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 412ms/step
# 2022년의 CO2 배출량 예측값:  [[387.28885]]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# 데이터 선택
df_co2 = df[(df['Composite_Indicators'] == 'CO2 emissions (MMtonnes CO2)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_co2.columns = ['CO2_emissions']

df_biomass = df[(df['Composite_Indicators'] == 'Biomass and waste (billion kWh)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_biomass.columns = ['Biomass_waste']

df_combined = df_co2.join(df_biomass)

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0,1))
df_combined_scaled = scaler.fit_transform(df_combined)

# 트레이닝셋, 테스트셋 분리
train_size = int(len(df_combined_scaled) * 0.7)
train, test = df_combined_scaled[0:train_size, :], df_combined_scaled[train_size:len(df_combined_scaled), :]

# X, Y 데이터셋 생성
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), :]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# LSTM 모델 생성
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# 2022년 예측
last_val = df_combined_scaled[-1]
last_val_scaled = last_val.reshape(1, 1, -1)
next_val = model.predict(last_val_scaled)
print("2022년의 CO2 배출량 예측값: ", scaler.inverse_transform(next_val))
# Out:
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:757: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:595: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:604: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# Epoch 1/100
# 27/27 - 2s - loss: 0.1933 - 2s/epoch - 58ms/step
# Epoch 2/100
# 27/27 - 0s - loss: 0.1665 - 65ms/epoch - 2ms/step
# Epoch 3/100
# 27/27 - 0s - loss: 0.1440 - 84ms/epoch - 3ms/step
# Epoch 4/100
# 27/27 - 0s - loss: 0.1215 - 87ms/epoch - 3ms/step
# Epoch 5/100
# 27/27 - 0s - loss: 0.1020 - 89ms/epoch - 3ms/step
# Epoch 6/100
# 27/27 - 0s - loss: 0.0858 - 82ms/epoch - 3ms/step
# Epoch 7/100
# 27/27 - 0s - loss: 0.0711 - 80ms/epoch - 3ms/step
# Epoch 8/100
# 27/27 - 0s - loss: 0.0605 - 87ms/epoch - 3ms/step
# Epoch 9/100
# 27/27 - 0s - loss: 0.0521 - 89ms/epoch - 3ms/step
# Epoch 10/100
# 27/27 - 0s - loss: 0.0456 - 81ms/epoch - 3ms/step
# Epoch 11/100
# 27/27 - 0s - loss: 0.0421 - 82ms/epoch - 3ms/step
# Epoch 12/100
# 27/27 - 0s - loss: 0.0379 - 85ms/epoch - 3ms/step
# Epoch 13/100
# 27/27 - 0s - loss: 0.0353 - 83ms/epoch - 3ms/step
# Epoch 14/100
# 27/27 - 0s - loss: 0.0334 - 81ms/epoch - 3ms/step
# Epoch 15/100
# 27/27 - 0s - loss: 0.0311 - 83ms/epoch - 3ms/step
# Epoch 16/100
# 27/27 - 0s - loss: 0.0292 - 82ms/epoch - 3ms/step
# Epoch 17/100
# 27/27 - 0s - loss: 0.0277 - 75ms/epoch - 3ms/step
# Epoch 18/100
# 27/27 - 0s - loss: 0.0265 - 78ms/epoch - 3ms/step
# Epoch 19/100
# 27/27 - 0s - loss: 0.0243 - 82ms/epoch - 3ms/step
# Epoch 20/100
# 27/27 - 0s - loss: 0.0227 - 77ms/epoch - 3ms/step
# Epoch 21/100
# 27/27 - 0s - loss: 0.0213 - 85ms/epoch - 3ms/step
# Epoch 22/100
# 27/27 - 0s - loss: 0.0197 - 81ms/epoch - 3ms/step
# Epoch 23/100
# 27/27 - 0s - loss: 0.0183 - 85ms/epoch - 3ms/step
# Epoch 24/100
# 27/27 - 0s - loss: 0.0171 - 82ms/epoch - 3ms/step
# Epoch 25/100
# 27/27 - 0s - loss: 0.0157 - 85ms/epoch - 3ms/step
# Epoch 26/100
# 27/27 - 0s - loss: 0.0145 - 81ms/epoch - 3ms/step
# Epoch 27/100
# 27/27 - 0s - loss: 0.0136 - 75ms/epoch - 3ms/step
# Epoch 28/100
# 27/27 - 0s - loss: 0.0124 - 79ms/epoch - 3ms/step
# Epoch 29/100
# 27/27 - 0s - loss: 0.0112 - 76ms/epoch - 3ms/step
# Epoch 30/100
# 27/27 - 0s - loss: 0.0104 - 76ms/epoch - 3ms/step
# Epoch 31/100
# 27/27 - 0s - loss: 0.0095 - 80ms/epoch - 3ms/step
# Epoch 32/100
# 27/27 - 0s - loss: 0.0087 - 78ms/epoch - 3ms/step
# Epoch 33/100
# 27/27 - 0s - loss: 0.0079 - 76ms/epoch - 3ms/step
# Epoch 34/100
# 27/27 - 0s - loss: 0.0073 - 79ms/epoch - 3ms/step
# Epoch 35/100
# 27/27 - 0s - loss: 0.0067 - 80ms/epoch - 3ms/step
# Epoch 36/100
# 27/27 - 0s - loss: 0.0063 - 77ms/epoch - 3ms/step
# Epoch 37/100
# 27/27 - 0s - loss: 0.0057 - 80ms/epoch - 3ms/step
# Epoch 38/100
# 27/27 - 0s - loss: 0.0053 - 79ms/epoch - 3ms/step
# Epoch 39/100
# 27/27 - 0s - loss: 0.0049 - 80ms/epoch - 3ms/step
# Epoch 40/100
# 27/27 - 0s - loss: 0.0046 - 75ms/epoch - 3ms/step
# Epoch 41/100
# 27/27 - 0s - loss: 0.0043 - 78ms/epoch - 3ms/step
# Epoch 42/100
# 27/27 - 0s - loss: 0.0041 - 77ms/epoch - 3ms/step
# Epoch 43/100
# 27/27 - 0s - loss: 0.0039 - 79ms/epoch - 3ms/step
# Epoch 44/100
# 27/27 - 0s - loss: 0.0038 - 77ms/epoch - 3ms/step
# Epoch 45/100
# 27/27 - 0s - loss: 0.0035 - 85ms/epoch - 3ms/step
# Epoch 46/100
# 27/27 - 0s - loss: 0.0034 - 85ms/epoch - 3ms/step
# Epoch 47/100
# 27/27 - 0s - loss: 0.0033 - 84ms/epoch - 3ms/step
# Epoch 48/100
# 27/27 - 0s - loss: 0.0032 - 80ms/epoch - 3ms/step
# Epoch 49/100
# 27/27 - 0s - loss: 0.0031 - 77ms/epoch - 3ms/step
# Epoch 50/100
# 27/27 - 0s - loss: 0.0030 - 84ms/epoch - 3ms/step
# Epoch 51/100
# 27/27 - 0s - loss: 0.0029 - 76ms/epoch - 3ms/step
# Epoch 52/100
# 27/27 - 0s - loss: 0.0028 - 85ms/epoch - 3ms/step
# Epoch 53/100
# 27/27 - 0s - loss: 0.0028 - 79ms/epoch - 3ms/step
# Epoch 54/100
# 27/27 - 0s - loss: 0.0027 - 75ms/epoch - 3ms/step
# Epoch 55/100
# 27/27 - 0s - loss: 0.0027 - 75ms/epoch - 3ms/step
# Epoch 56/100
# 27/27 - 0s - loss: 0.0026 - 75ms/epoch - 3ms/step
# Epoch 57/100
# 27/27 - 0s - loss: 0.0026 - 77ms/epoch - 3ms/step
# Epoch 58/100
# 27/27 - 0s - loss: 0.0025 - 77ms/epoch - 3ms/step
# Epoch 59/100
# 27/27 - 0s - loss: 0.0025 - 79ms/epoch - 3ms/step
# Epoch 60/100
# 27/27 - 0s - loss: 0.0024 - 74ms/epoch - 3ms/step
# Epoch 61/100
# 27/27 - 0s - loss: 0.0024 - 57ms/epoch - 2ms/step
# Epoch 62/100
# 27/27 - 0s - loss: 0.0023 - 76ms/epoch - 3ms/step
# Epoch 63/100
# 27/27 - 0s - loss: 0.0023 - 79ms/epoch - 3ms/step
# Epoch 64/100
# 27/27 - 0s - loss: 0.0023 - 73ms/epoch - 3ms/step
# Epoch 65/100
# 27/27 - 0s - loss: 0.0022 - 71ms/epoch - 3ms/step
# Epoch 66/100
# 27/27 - 0s - loss: 0.0022 - 74ms/epoch - 3ms/step
# Epoch 67/100
# 27/27 - 0s - loss: 0.0021 - 75ms/epoch - 3ms/step
# Epoch 68/100
# 27/27 - 0s - loss: 0.0021 - 76ms/epoch - 3ms/step
# Epoch 69/100
# 27/27 - 0s - loss: 0.0021 - 73ms/epoch - 3ms/step
# Epoch 70/100
# 27/27 - 0s - loss: 0.0021 - 77ms/epoch - 3ms/step
# Epoch 71/100
# 27/27 - 0s - loss: 0.0021 - 79ms/epoch - 3ms/step
# Epoch 72/100
# 27/27 - 0s - loss: 0.0020 - 81ms/epoch - 3ms/step
# Epoch 73/100
# 27/27 - 0s - loss: 0.0020 - 76ms/epoch - 3ms/step
# Epoch 74/100
# 27/27 - 0s - loss: 0.0020 - 74ms/epoch - 3ms/step
# Epoch 75/100
# 27/27 - 0s - loss: 0.0019 - 78ms/epoch - 3ms/step
# Epoch 76/100
# 27/27 - 0s - loss: 0.0019 - 76ms/epoch - 3ms/step
# Epoch 77/100
# 27/27 - 0s - loss: 0.0019 - 74ms/epoch - 3ms/step
# Epoch 78/100
# 27/27 - 0s - loss: 0.0019 - 81ms/epoch - 3ms/step
# Epoch 79/100
# 27/27 - 0s - loss: 0.0019 - 77ms/epoch - 3ms/step
# Epoch 80/100
# 27/27 - 0s - loss: 0.0018 - 75ms/epoch - 3ms/step
# Epoch 81/100
# 27/27 - 0s - loss: 0.0019 - 75ms/epoch - 3ms/step
# Epoch 82/100
# 27/27 - 0s - loss: 0.0018 - 80ms/epoch - 3ms/step
# Epoch 83/100
# 27/27 - 0s - loss: 0.0018 - 80ms/epoch - 3ms/step
# Epoch 84/100
# 27/27 - 0s - loss: 0.0018 - 78ms/epoch - 3ms/step
# Epoch 85/100
# 27/27 - 0s - loss: 0.0018 - 80ms/epoch - 3ms/step
# Epoch 86/100
# 27/27 - 0s - loss: 0.0017 - 76ms/epoch - 3ms/step
# Epoch 87/100
# 27/27 - 0s - loss: 0.0017 - 78ms/epoch - 3ms/step
# Epoch 88/100
# 27/27 - 0s - loss: 0.0017 - 77ms/epoch - 3ms/step
# Epoch 89/100
# 27/27 - 0s - loss: 0.0017 - 82ms/epoch - 3ms/step
# Epoch 90/100
# 27/27 - 0s - loss: 0.0017 - 78ms/epoch - 3ms/step
# Epoch 91/100
# 27/27 - 0s - loss: 0.0016 - 81ms/epoch - 3ms/step
# Epoch 92/100
# 27/27 - 0s - loss: 0.0016 - 80ms/epoch - 3ms/step
# Epoch 93/100
# 27/27 - 0s - loss: 0.0016 - 89ms/epoch - 3ms/step
# Epoch 94/100
# 27/27 - 0s - loss: 0.0016 - 82ms/epoch - 3ms/step
# Epoch 95/100
# 27/27 - 0s - loss: 0.0016 - 72ms/epoch - 3ms/step
# Epoch 96/100
# 27/27 - 0s - loss: 0.0016 - 76ms/epoch - 3ms/step
# Epoch 97/100
# 27/27 - 0s - loss: 0.0016 - 79ms/epoch - 3ms/step
# Epoch 98/100
# 27/27 - 0s - loss: 0.0016 - 80ms/epoch - 3ms/step
# Epoch 99/100
# 27/27 - 0s - loss: 0.0016 - 79ms/epoch - 3ms/step
# Epoch 100/100
# 27/27 - 0s - loss: 0.0016 - 81ms/epoch - 3ms/step
# 1/1 [==============================] - 0s 476ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\k-project\source\model\RNN_함현욱.ipynb 셀 5 line 4
#      <a href='vscode-notebook-cell:/c%3A/k-project/source/model/RNN_%ED%95%A8%ED%98%84%EC%9A%B1.ipynb#W4sZmlsZQ%3D%3D?line=45'>46</a> last_val_scaled = last_val.reshape(1, 1, -1)
#      <a href='vscode-notebook-cell:/c%3A/k-project/source/model/RNN_%ED%95%A8%ED%98%84%EC%9A%B1.ipynb#W4sZmlsZQ%3D%3D?line=46'>47</a> next_val = model.predict(last_val_scaled)
# ---> <a href='vscode-notebook-cell:/c%3A/k-project/source/model/RNN_%ED%95%A8%ED%98%84%EC%9A%B1.ipynb#W4sZmlsZQ%3D%3D?line=47'>48</a> print("2022년의 CO2 배출량 예측값: ", scaler.inverse_transform(next_val))
#
# File c:\Users\thesw\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_data.py:532, in MinMaxScaler.inverse_transform(self, X)
#     526 check_is_fitted(self)
#     528 X = check_array(
#     529     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     530 )
# --> 532 X -= self.min_
#     533 X /= self.scale_
#     534 return X
#
# ValueError: non-broadcastable output operand with shape (1,1) doesn't match the broadcast shape (1,2)
