# %%
'''
다 함께 하는 작업 공간이기 때문에 경로나 파일 명 등을 통일 해야 할 것 같습니다.
그렇게 하지 않으면 경로 때문에 매번 새로운 커밋이 생성 됩니다.
'''

import os

# 현재 작업 디렉토리 확인
current_directory = os.getcwd()
print("Current directory:", current_directory)

# 필요한 CSV 파일이 있는 디렉토리로 변경
target_directory = "C:/k-project/raw_datasets/최종" # 해당 코드 부분의 경로를 동일하게 하거나 / 깃 리파지토리 안에 파일을 집어 넣는 작업 필요.      
os.chdir(target_directory)

import pandas as pd

# CSV 파일 불러오기
csv_filename = "최종_수정02_국가별_시계열_데이터_전처리(인구+GDP).csv"  # CSV 파일명. 파일명을 모두 동일하게 해야합니다.
df = pd.read_csv(csv_filename)

# 데이터 확인
print(df.head())
# Out:
# Current directory: c:\k-project\source\model
#      COUNTRY                 Composite_Indicators        1980        1981  \
# 0  Australia      Biomass and waste (billion kWh)    0.400000    0.400000
# 1  Australia         CO2 emissions (MMtonnes CO2)  221.314466  223.053852
# 2  Australia                      Coal (quad Btu)    1.287102    1.317761
# 3  Australia         Coal and coke (MMtonnes CO2)  126.716798  129.723177
# 4  Australia  Consumed natural gas (MMtonnes CO2)   17.989712   20.559671
#
#          1982        1983        1984        1985        1986        1987  \
# 0    0.500000    0.400000    0.400000    0.400000    0.400000    0.400000
# 1  230.129715  219.685227  227.994782  240.581272  241.444382  259.333455
# 2    1.394639    1.325105    1.267020    1.362507    1.354289    1.488758
# 3  133.863175  125.379483  120.132560  129.281043  127.917222  140.745976
# 4   22.738549   23.073761   24.605560   26.309368   28.718725   29.439871
#
#    ...        2012        2013        2014        2015        2016  \
# 0  ...    3.043000    3.152000    3.511000    3.608000    3.722000
# 1  ...  393.234943  385.146233  377.521170  384.191753  395.971861
# 2  ...    1.944928    1.818970    1.726155    1.777427    1.851000
# 3  ...  173.910304  161.363707  152.786961  157.999239  163.960594
# 4  ...   71.402493   73.610853   75.233517   76.261073   82.848989
#
#          2017        2018        2019        2020        2021
# 0    3.501000    3.518000    3.496000    3.352000    2.784000
# 1  406.642388  411.530154  406.113146  372.647180  377.152725
# 2    1.834908    1.750055    1.696931    1.602948    1.670752
# 3  162.853470  165.699363  160.967880  151.627761  157.961453
# 4   86.614156   85.951616   87.757573   86.105841   81.757000
#
# [5 rows x 44 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
# Out:
# C:\Users\vlrms\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\requests\__init__.py:104: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (5.0.0)/charset_normalizer (2.0.10) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
df.head(10)
# Out:
#      COUNTRY                 Composite_Indicators        1980        1981  \
# 0  Australia      Biomass and waste (billion kWh)    0.400000    0.400000
# 1  Australia         CO2 emissions (MMtonnes CO2)  221.314466  223.053852
# 2  Australia                      Coal (quad Btu)    1.287102    1.317761
# 3  Australia         Coal and coke (MMtonnes CO2)  126.716798  129.723177
# 4  Australia  Consumed natural gas (MMtonnes CO2)   17.989712   20.559671
# 5  Australia               Consumption (quad Btu)    2.985436    3.049886
# 6  Australia           Fossil fuels (billion kWh)   74.538000   78.934000
# 7  Australia                                  GDP  373.192500  388.609100
# 8  Australia             Generation (billion kWh)   87.393000   92.911000
# 9  Australia             Geothermal (billion kWh)    0.000000    0.000000
#
#          1982        1983        1984        1985        1986        1987  \
# 0    0.500000    0.400000    0.400000    0.400000    0.400000    0.400000
# 1  230.129715  219.685227  227.994782  240.581272  241.444382  259.333455
# 2    1.394639    1.325105    1.267020    1.362507    1.354289    1.488758
# 3  133.863175  125.379483  120.132560  129.281043  127.917222  140.745976
# 4   22.738549   23.073761   24.605560   26.309368   28.718725   29.439871
# 5    3.231536    3.106749    3.149405    3.289446    3.339458    3.510146
# 6   83.193000   85.971000   91.686000   97.054000  101.933000  108.543000
# 7  389.348700  386.844800  412.802700  433.462200  442.469000  464.680900
# 8   96.736000   98.048000  103.716000  110.425000  116.272000  121.915000
# 9    0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
#
#    ...         2012         2013         2014         2015         2016  \
# 0  ...     3.043000     3.152000     3.511000     3.608000     3.722000
# 1  ...   393.234943   385.146233   377.521170   384.191753   395.971861
# 2  ...     1.944928     1.818970     1.726155     1.777427     1.851000
# 3  ...   173.910304   161.363707   152.786961   157.999239   163.960594
# 4  ...    71.402493    73.610853    75.233517    76.261073    82.848989
# 5  ...     5.808348     5.817068     5.752163     5.778272     6.018588
# 6  ...   206.632233   195.695324   205.342418   197.440256   207.429731
# 7  ...  1036.675000  1059.512000  1086.628000  1111.436000  1141.364000
# 8  ...   233.296073   229.875825   241.555085   230.763959   245.875090
# 9  ...     0.000996     0.000996     0.000996     0.000996     0.000000
#
#           2017         2018         2019         2020         2021
# 0     3.501000     3.518000     3.496000     3.352000     2.784000
# 1   406.642388   411.530154   406.113146   372.647180   377.152725
# 2     1.834908     1.750055     1.696931     1.602948     1.670752
# 3   162.853470   165.699363   160.967880   151.627761   157.961453
# 4    86.614156    85.951616    87.757573    86.105841    81.757000
# 5     6.199736     6.167649     6.206137     5.832998     5.922681
# 6   209.031696   207.429732   196.189993   186.748435   175.388763
# 7  1168.544000  1201.440000  1224.843000  1202.426000  1265.030000
# 8   249.738884   250.230091   249.594586   250.658027   246.785906
# 9     0.000996     0.000000     0.000000     0.000000     0.000000
#
# [10 rows x 44 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# co2배출량과 호주 데이터만 선택
df_co2 = df[(df['Composite_Indicators'] == 'CO2 emissions (MMtonnes CO2)') & (df['COUNTRY'] == 'Australia')]

# 'Composite_Indicators'와 'COUNTRY' 컬럼을 삭제하고, 데이터프레임을 전치(transpose)
# 전치 작업으로 인해, 각 연도가 행으로, CO2 배출량이 열로 배치
df_co2 = df_co2.drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_co2.columns = ['CO2_emissions']


# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0,1))
df_co2_scaled = scaler.fit_transform(df_co2)

# 트레이닝셋, 테스트셋 분리
train_size = int(len(df_co2_scaled) * 0.7)
train, test = df_co2_scaled[0:train_size, :], df_co2_scaled[train_size:len(df_co2_scaled), :]

# X, Y 데이터셋 생성
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# LSTM 모델 생성
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# 2022년 예측
last_val = df_co2_scaled[-1]
last_val_scaled = last_val.reshape(-1, 1)
next_val = model.predict(last_val_scaled)
print("2022년의 CO2 배출량 예측값: ", scaler.inverse_transform(next_val))
# Out:
# Epoch 1/100
# 27/27 - 2s - loss: 0.3084 - 2s/epoch - 59ms/step
# Epoch 2/100
# 27/27 - 0s - loss: 0.2673 - 49ms/epoch - 2ms/step
# Epoch 3/100
# 27/27 - 0s - loss: 0.2320 - 42ms/epoch - 2ms/step
# Epoch 4/100
# 27/27 - 0s - loss: 0.2037 - 36ms/epoch - 1ms/step
# Epoch 5/100
# 27/27 - 0s - loss: 0.1770 - 34ms/epoch - 1ms/step
# Epoch 6/100
# 27/27 - 0s - loss: 0.1574 - 34ms/epoch - 1ms/step
# Epoch 7/100
# 27/27 - 0s - loss: 0.1404 - 35ms/epoch - 1ms/step
# Epoch 8/100
# 27/27 - 0s - loss: 0.1246 - 35ms/epoch - 1ms/step
# Epoch 9/100
# 27/27 - 0s - loss: 0.1127 - 36ms/epoch - 1ms/step
# Epoch 10/100
# 27/27 - 0s - loss: 0.1023 - 35ms/epoch - 1ms/step
# Epoch 11/100
# 27/27 - 0s - loss: 0.0938 - 34ms/epoch - 1ms/step
# Epoch 12/100
# 27/27 - 0s - loss: 0.0873 - 35ms/epoch - 1ms/step
# Epoch 13/100
# 27/27 - 0s - loss: 0.0813 - 37ms/epoch - 1ms/step
# Epoch 14/100
# 27/27 - 0s - loss: 0.0764 - 36ms/epoch - 1ms/step
# Epoch 15/100
# 27/27 - 0s - loss: 0.0733 - 37ms/epoch - 1ms/step
# Epoch 16/100
# 27/27 - 0s - loss: 0.0697 - 34ms/epoch - 1ms/step
# Epoch 17/100
# 27/27 - 0s - loss: 0.0672 - 35ms/epoch - 1ms/step
# Epoch 18/100
# 27/27 - 0s - loss: 0.0650 - 37ms/epoch - 1ms/step
# Epoch 19/100
# 27/27 - 0s - loss: 0.0630 - 46ms/epoch - 2ms/step
# Epoch 20/100
# 27/27 - 0s - loss: 0.0610 - 49ms/epoch - 2ms/step
# Epoch 21/100
# 27/27 - 0s - loss: 0.0597 - 44ms/epoch - 2ms/step
# Epoch 22/100
# 27/27 - 0s - loss: 0.0582 - 36ms/epoch - 1ms/step
# Epoch 23/100
# 27/27 - 0s - loss: 0.0571 - 34ms/epoch - 1ms/step
# Epoch 24/100
# 27/27 - 0s - loss: 0.0558 - 34ms/epoch - 1ms/step
# Epoch 25/100
# 27/27 - 0s - loss: 0.0546 - 35ms/epoch - 1ms/step
# Epoch 26/100
# 27/27 - 0s - loss: 0.0534 - 34ms/epoch - 1ms/step
# Epoch 27/100
# 27/27 - 0s - loss: 0.0522 - 42ms/epoch - 2ms/step
# Epoch 28/100
# 27/27 - 0s - loss: 0.0511 - 42ms/epoch - 2ms/step
# Epoch 29/100
# 27/27 - 0s - loss: 0.0500 - 41ms/epoch - 2ms/step
# Epoch 30/100
# 27/27 - 0s - loss: 0.0492 - 49ms/epoch - 2ms/step
# Epoch 31/100
# 27/27 - 0s - loss: 0.0477 - 35ms/epoch - 1ms/step
# Epoch 32/100
# 27/27 - 0s - loss: 0.0467 - 37ms/epoch - 1ms/step
# Epoch 33/100
# 27/27 - 0s - loss: 0.0455 - 35ms/epoch - 1ms/step
# Epoch 34/100
# 27/27 - 0s - loss: 0.0444 - 35ms/epoch - 1ms/step
# Epoch 35/100
# 27/27 - 0s - loss: 0.0434 - 35ms/epoch - 1ms/step
# Epoch 36/100
# 27/27 - 0s - loss: 0.0428 - 44ms/epoch - 2ms/step
# Epoch 37/100
# 27/27 - 0s - loss: 0.0412 - 41ms/epoch - 2ms/step
# Epoch 38/100
# 27/27 - 0s - loss: 0.0403 - 38ms/epoch - 1ms/step
# Epoch 39/100
# 27/27 - 0s - loss: 0.0390 - 38ms/epoch - 1ms/step
# Epoch 40/100
# 27/27 - 0s - loss: 0.0379 - 39ms/epoch - 1ms/step
# Epoch 41/100
# 27/27 - 0s - loss: 0.0368 - 37ms/epoch - 1ms/step
# Epoch 42/100
# 27/27 - 0s - loss: 0.0357 - 34ms/epoch - 1ms/step
# Epoch 43/100
# 27/27 - 0s - loss: 0.0347 - 34ms/epoch - 1ms/step
# Epoch 44/100
# 27/27 - 0s - loss: 0.0337 - 43ms/epoch - 2ms/step
# Epoch 45/100
# 27/27 - 0s - loss: 0.0326 - 45ms/epoch - 2ms/step
# Epoch 46/100
# 27/27 - 0s - loss: 0.0315 - 40ms/epoch - 1ms/step
# Epoch 47/100
# 27/27 - 0s - loss: 0.0306 - 45ms/epoch - 2ms/step
# Epoch 48/100
# 27/27 - 0s - loss: 0.0299 - 41ms/epoch - 2ms/step
# Epoch 49/100
# 27/27 - 0s - loss: 0.0283 - 40ms/epoch - 1ms/step
# Epoch 50/100
# 27/27 - 0s - loss: 0.0273 - 40ms/epoch - 1ms/step
# Epoch 51/100
# 27/27 - 0s - loss: 0.0261 - 37ms/epoch - 1ms/step
# Epoch 52/100
# 27/27 - 0s - loss: 0.0252 - 35ms/epoch - 1ms/step
# Epoch 53/100
# 27/27 - 0s - loss: 0.0242 - 35ms/epoch - 1ms/step
# Epoch 54/100
# 27/27 - 0s - loss: 0.0231 - 34ms/epoch - 1ms/step
# Epoch 55/100
# 27/27 - 0s - loss: 0.0222 - 35ms/epoch - 1ms/step
# Epoch 56/100
# 27/27 - 0s - loss: 0.0211 - 77ms/epoch - 3ms/step
# Epoch 57/100
# 27/27 - 0s - loss: 0.0202 - 37ms/epoch - 1ms/step
# Epoch 58/100
# 27/27 - 0s - loss: 0.0192 - 34ms/epoch - 1ms/step
# Epoch 59/100
# 27/27 - 0s - loss: 0.0184 - 34ms/epoch - 1ms/step
# Epoch 60/100
# 27/27 - 0s - loss: 0.0176 - 34ms/epoch - 1ms/step
# Epoch 61/100
# 27/27 - 0s - loss: 0.0165 - 34ms/epoch - 1ms/step
# Epoch 62/100
# 27/27 - 0s - loss: 0.0158 - 39ms/epoch - 1ms/step
# Epoch 63/100
# 27/27 - 0s - loss: 0.0150 - 42ms/epoch - 2ms/step
# Epoch 64/100
# 27/27 - 0s - loss: 0.0140 - 41ms/epoch - 2ms/step
# Epoch 65/100
# 27/27 - 0s - loss: 0.0132 - 39ms/epoch - 1ms/step
# Epoch 66/100
# 27/27 - 0s - loss: 0.0125 - 34ms/epoch - 1ms/step
# Epoch 67/100
# 27/27 - 0s - loss: 0.0118 - 37ms/epoch - 1ms/step
# Epoch 68/100
# 27/27 - 0s - loss: 0.0110 - 32ms/epoch - 1ms/step
# Epoch 69/100
# 27/27 - 0s - loss: 0.0103 - 33ms/epoch - 1ms/step
# Epoch 70/100
# 27/27 - 0s - loss: 0.0097 - 33ms/epoch - 1ms/step
# Epoch 71/100
# 27/27 - 0s - loss: 0.0092 - 37ms/epoch - 1ms/step
# Epoch 72/100
# 27/27 - 0s - loss: 0.0085 - 37ms/epoch - 1ms/step
# Epoch 73/100
# 27/27 - 0s - loss: 0.0079 - 36ms/epoch - 1ms/step
# Epoch 74/100
# 27/27 - 0s - loss: 0.0074 - 38ms/epoch - 1ms/step
# Epoch 75/100
# 27/27 - 0s - loss: 0.0069 - 35ms/epoch - 1ms/step
# Epoch 76/100
# 27/27 - 0s - loss: 0.0064 - 36ms/epoch - 1ms/step
# Epoch 77/100
# 27/27 - 0s - loss: 0.0060 - 32ms/epoch - 1ms/step
# Epoch 78/100
# 27/27 - 0s - loss: 0.0056 - 31ms/epoch - 1ms/step
# Epoch 79/100
# 27/27 - 0s - loss: 0.0051 - 38ms/epoch - 1ms/step
# Epoch 80/100
# 27/27 - 0s - loss: 0.0048 - 51ms/epoch - 2ms/step
# Epoch 81/100
# 27/27 - 0s - loss: 0.0045 - 36ms/epoch - 1ms/step
# Epoch 82/100
# 27/27 - 0s - loss: 0.0042 - 36ms/epoch - 1ms/step
# Epoch 83/100
# 27/27 - 0s - loss: 0.0039 - 36ms/epoch - 1ms/step
# Epoch 84/100
# 27/27 - 0s - loss: 0.0036 - 36ms/epoch - 1ms/step
# Epoch 85/100
# 27/27 - 0s - loss: 0.0034 - 32ms/epoch - 1ms/step
# Epoch 86/100
# 27/27 - 0s - loss: 0.0031 - 35ms/epoch - 1ms/step
# Epoch 87/100
# 27/27 - 0s - loss: 0.0030 - 36ms/epoch - 1ms/step
# Epoch 88/100
# 27/27 - 0s - loss: 0.0028 - 37ms/epoch - 1ms/step
# Epoch 89/100
# 27/27 - 0s - loss: 0.0026 - 40ms/epoch - 1ms/step
# Epoch 90/100
# 27/27 - 0s - loss: 0.0025 - 38ms/epoch - 1ms/step
# Epoch 91/100
# 27/27 - 0s - loss: 0.0024 - 40ms/epoch - 1ms/step
# Epoch 92/100
# 27/27 - 0s - loss: 0.0022 - 39ms/epoch - 1ms/step
# Epoch 93/100
# 27/27 - 0s - loss: 0.0021 - 45ms/epoch - 2ms/step
# Epoch 94/100
# 27/27 - 0s - loss: 0.0021 - 42ms/epoch - 2ms/step
# Epoch 95/100
# 27/27 - 0s - loss: 0.0020 - 40ms/epoch - 1ms/step
# Epoch 96/100
# 27/27 - 0s - loss: 0.0019 - 41ms/epoch - 2ms/step
# Epoch 97/100
# 27/27 - 0s - loss: 0.0018 - 36ms/epoch - 1ms/step
# Epoch 98/100
# 27/27 - 0s - loss: 0.0018 - 35ms/epoch - 1ms/step
# Epoch 99/100
# 27/27 - 0s - loss: 0.0018 - 34ms/epoch - 1ms/step
# Epoch 100/100
# 27/27 - 0s - loss: 0.0017 - 34ms/epoch - 1ms/step
# 1/1 [==============================] - 0s 409ms/step
# 2022년의 CO2 배출량 예측값:  [[377.8474]]

# %%
# 데이터 선택
df_co2 = df[(df['Composite_Indicators'] == 'CO2 emissions (MMtonnes CO2)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_co2.columns = ['CO2_emissions']

df_biomass = df[(df['Composite_Indicators'] == 'Biomass and waste (billion kWh)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_biomass.columns = ['Biomass_waste']

df_combined = df_co2.join(df_biomass)

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0,1))
df_combined_scaled = scaler.fit_transform(df_combined)
df_combined
# Out:
#       CO2_emissions  Biomass_waste
# 1980     221.314466          0.400
# 1981     223.053852          0.400
# 1982     230.129715          0.500
# 1983     219.685227          0.400
# 1984     227.994782          0.400
# 1985     240.581272          0.400
# 1986     241.444382          0.400
# 1987     259.333455          0.400
# 1988     262.533088          0.700
# 1989     280.535254          0.800
# 1990     267.594470          0.750
# 1991     266.285873          0.770
# 1992     272.517534          0.670
# 1993     276.818638          0.670
# 1994     281.423610          0.670
# 1995     289.400020          0.720
# 1996     305.245391          0.930
# 1997     313.354869          0.970
# 1998     329.104173          1.030
# 1999     337.320509          1.130
# 2000     339.399972          1.130
# 2001     343.226803          1.350
# 2002     353.274215          1.580
# 2003     351.729506          1.620
# 2004     364.075126          1.860
# 2005     369.934070          3.830
# 2006     375.296665          3.910
# 2007     385.301034          3.950
# 2008     384.431726          4.596
# 2009     396.011138          2.815
# 2010     391.728752          2.777
# 2011     389.552897          2.102
# 2012     393.234943          3.043
# 2013     385.146233          3.152
# 2014     377.521170          3.511
# 2015     384.191753          3.608
# 2016     395.971861          3.722
# 2017     406.642388          3.501
# 2018     411.530154          3.518
# 2019     406.113146          3.496
# 2020     372.647180          3.352
# 2021     377.152725          2.784

# %%
df.head()
# Out:
#      COUNTRY                 Composite_Indicators        1980        1981  \
# 0  Australia      Biomass and waste (billion kWh)    0.400000    0.400000
# 1  Australia         CO2 emissions (MMtonnes CO2)  221.314466  223.053852
# 2  Australia                      Coal (quad Btu)    1.287102    1.317761
# 3  Australia         Coal and coke (MMtonnes CO2)  126.716798  129.723177
# 4  Australia  Consumed natural gas (MMtonnes CO2)   17.989712   20.559671
#
#          1982        1983        1984        1985        1986        1987  \
# 0    0.500000    0.400000    0.400000    0.400000    0.400000    0.400000
# 1  230.129715  219.685227  227.994782  240.581272  241.444382  259.333455
# 2    1.394639    1.325105    1.267020    1.362507    1.354289    1.488758
# 3  133.863175  125.379483  120.132560  129.281043  127.917222  140.745976
# 4   22.738549   23.073761   24.605560   26.309368   28.718725   29.439871
#
#    ...        2012        2013        2014        2015        2016  \
# 0  ...    3.043000    3.152000    3.511000    3.608000    3.722000
# 1  ...  393.234943  385.146233  377.521170  384.191753  395.971861
# 2  ...    1.944928    1.818970    1.726155    1.777427    1.851000
# 3  ...  173.910304  161.363707  152.786961  157.999239  163.960594
# 4  ...   71.402493   73.610853   75.233517   76.261073   82.848989
#
#          2017        2018        2019        2020        2021
# 0    3.501000    3.518000    3.496000    3.352000    2.784000
# 1  406.642388  411.530154  406.113146  372.647180  377.152725
# 2    1.834908    1.750055    1.696931    1.602948    1.670752
# 3  162.853470  165.699363  160.967880  151.627761  157.961453
# 4   86.614156   85.951616   87.757573   86.105841   81.757000
#
# [5 rows x 44 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 44 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   COUNTRY               442 non-null    object
#  1   Composite_Indicators  442 non-null    object
#  2   1980                  442 non-null    float64
#  3   1981                  442 non-null    float64
#  4   1982                  442 non-null    float64
#  5   1983                  442 non-null    float64
#  6   1984                  442 non-null    float64
#  7   1985                  442 non-null    float64
#  8   1986                  442 non-null    float64
#  9   1987                  442 non-null    float64
#  10  1988                  442 non-null    float64
#  11  1989                  442 non-null    float64
#  12  1990                  442 non-null    float64
#  13  1991                  442 non-null    float64
#  14  1992                  442 non-null    float64
#  15  1993                  442 non-null    float64
#  16  1994                  442 non-null    float64
#  17  1995                  442 non-null    float64
#  18  1996                  442 non-null    float64
#  19  1997                  442 non-null    float64
#  20  1998                  442 non-null    float64
#  21  1999                  442 non-null    float64
#  22  2000                  442 non-null    float64
#  23  2001                  442 non-null    float64
#  24  2002                  442 non-null    float64
#  25  2003                  442 non-null    float64
#  26  2004                  442 non-null    float64
#  27  2005                  442 non-null    float64
#  28  2006                  442 non-null    float64
#  29  2007                  442 non-null    float64
#  30  2008                  442 non-null    float64
#  31  2009                  442 non-null    float64
#  32  2010                  442 non-null    float64
#  33  2011                  442 non-null    float64
#  34  2012                  442 non-null    float64
#  35  2013                  442 non-null    float64
#  36  2014                  442 non-null    float64
#  37  2015                  442 non-null    float64
#  38  2016                  442 non-null    float64
#  39  2017                  442 non-null    float64
#  40  2018                  442 non-null    float64
#  41  2019                  442 non-null    float64
#  42  2020                  442 non-null    float64
#  43  2021                  442 non-null    float64
# dtypes: float64(42), object(2)
# memory usage: 152.1+ KB

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# 데이터 선택
df_co2 = df[(df['Composite_Indicators'] == 'CO2 emissions (MMtonnes CO2)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_co2.columns = ['CO2_emissions']

df_biomass = df[(df['Composite_Indicators'] == 'Biomass and waste (billion kWh)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_biomass.columns = ['Biomass_waste']

df_coal = df[(df['Composite_Indicators'] == 'Coal (quad Btu)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_coal.columns = ['Coal']

df_coal_coke = df[(df['Composite_Indicators'] == 'Coal and coke (MMtonnes CO2)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_coal_coke.columns = ['Coal and coke (MMtonnes CO2)']

df_natural_gas = df[(df['Composite_Indicators'] == 'Consumed natural gas (MMtonnes CO2)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_natural_gas.columns = ['Consumed natural gas (MMtonnes CO2)']

# 오브젝트 타입 수정 필요
df_consumption = df[(df['Composite_Indicators'] == 'Consumption (quad Btu)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_consumption.columns = ['Consumption (quad Btu)']

df_fuels = df[(df['Composite_Indicators'] == 'Fossil fuels (billion kWh)') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_fuels.columns = ['Fossil fuels (billion kWh)']

df_GDP = df[(df['Composite_Indicators'] == 'GDP') & (df['COUNTRY'] == 'Australia')].drop(columns=['Composite_Indicators', 'COUNTRY']).transpose()
df_GDP.columns = ['GDP']


df_combined = df_co2.join(df_biomass).join(df_coal).join(df_coal_coke).join(df_natural_gas).join(df_consumption).join(df_fuels).join(df_GDP)


# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0,1))
df_combined_scaled = scaler.fit_transform(df_combined)

# 트레이닝셋, 테스트셋 분리
train_size = int(len(df_combined_scaled) * 0.7)
train, test = df_combined_scaled[0:train_size, :], df_combined_scaled[train_size:len(df_combined_scaled), :]

# X, Y 데이터셋 생성
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), :]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# LSTM 모델 생성
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# 2022년 예측
last_val = df_combined_scaled[-1]
last_val_scaled = last_val.reshape(1, 1, -1)
next_val = model.predict(last_val_scaled)

# 스케일러 수정
co2_scaler = MinMaxScaler(feature_range=(0,1))
co2_scaler.min_, co2_scaler.scale_ = scaler.min_[0], scaler.scale_[0]

print("2022년의 CO2 배출량 예측값: ", co2_scaler.inverse_transform(next_val))
# Out:
# Epoch 1/100
# 27/27 - 1s - loss: 0.1235 - 1s/epoch - 53ms/step
# Epoch 2/100
# 27/27 - 0s - loss: 0.0834 - 36ms/epoch - 1ms/step
# Epoch 3/100
# 27/27 - 0s - loss: 0.0493 - 35ms/epoch - 1ms/step
# Epoch 4/100
# 27/27 - 0s - loss: 0.0285 - 36ms/epoch - 1ms/step
# Epoch 5/100
# 27/27 - 0s - loss: 0.0161 - 34ms/epoch - 1ms/step
# Epoch 6/100
# 27/27 - 0s - loss: 0.0099 - 41ms/epoch - 2ms/step
# Epoch 7/100
# 27/27 - 0s - loss: 0.0073 - 33ms/epoch - 1ms/step
# Epoch 8/100
# 27/27 - 0s - loss: 0.0062 - 34ms/epoch - 1ms/step
# Epoch 9/100
# 27/27 - 0s - loss: 0.0054 - 33ms/epoch - 1ms/step
# Epoch 10/100
# 27/27 - 0s - loss: 0.0048 - 32ms/epoch - 1ms/step
# Epoch 11/100
# 27/27 - 0s - loss: 0.0044 - 32ms/epoch - 1ms/step
# Epoch 12/100
# 27/27 - 0s - loss: 0.0039 - 36ms/epoch - 1ms/step
# Epoch 13/100
# 27/27 - 0s - loss: 0.0035 - 35ms/epoch - 1ms/step
# Epoch 14/100
# 27/27 - 0s - loss: 0.0032 - 34ms/epoch - 1ms/step
# Epoch 15/100
# 27/27 - 0s - loss: 0.0029 - 34ms/epoch - 1ms/step
# Epoch 16/100
# 27/27 - 0s - loss: 0.0027 - 34ms/epoch - 1ms/step
# Epoch 17/100
# 27/27 - 0s - loss: 0.0025 - 33ms/epoch - 1ms/step
# Epoch 18/100
# 27/27 - 0s - loss: 0.0024 - 33ms/epoch - 1ms/step
# Epoch 19/100
# 27/27 - 0s - loss: 0.0023 - 36ms/epoch - 1ms/step
# Epoch 20/100
# 27/27 - 0s - loss: 0.0022 - 34ms/epoch - 1ms/step
# Epoch 21/100
# 27/27 - 0s - loss: 0.0021 - 35ms/epoch - 1ms/step
# Epoch 22/100
# 27/27 - 0s - loss: 0.0020 - 37ms/epoch - 1ms/step
# Epoch 23/100
# 27/27 - 0s - loss: 0.0020 - 35ms/epoch - 1ms/step
# Epoch 24/100
# 27/27 - 0s - loss: 0.0019 - 34ms/epoch - 1ms/step
# Epoch 25/100
# 27/27 - 0s - loss: 0.0019 - 37ms/epoch - 1ms/step
# Epoch 26/100
# 27/27 - 0s - loss: 0.0019 - 42ms/epoch - 2ms/step
# Epoch 27/100
# 27/27 - 0s - loss: 0.0019 - 42ms/epoch - 2ms/step
# Epoch 28/100
# 27/27 - 0s - loss: 0.0019 - 33ms/epoch - 1ms/step
# Epoch 29/100
# 27/27 - 0s - loss: 0.0018 - 34ms/epoch - 1ms/step
# Epoch 30/100
# 27/27 - 0s - loss: 0.0019 - 48ms/epoch - 2ms/step
# Epoch 31/100
# 27/27 - 0s - loss: 0.0018 - 34ms/epoch - 1ms/step
# Epoch 32/100
# 27/27 - 0s - loss: 0.0018 - 32ms/epoch - 1ms/step
# Epoch 33/100
# 27/27 - 0s - loss: 0.0018 - 32ms/epoch - 1ms/step
# Epoch 34/100
# 27/27 - 0s - loss: 0.0018 - 33ms/epoch - 1ms/step
# Epoch 35/100
# 27/27 - 0s - loss: 0.0019 - 32ms/epoch - 1ms/step
# Epoch 36/100
# 27/27 - 0s - loss: 0.0018 - 33ms/epoch - 1ms/step
# Epoch 37/100
# 27/27 - 0s - loss: 0.0018 - 34ms/epoch - 1ms/step
# Epoch 38/100
# 27/27 - 0s - loss: 0.0018 - 36ms/epoch - 1ms/step
# Epoch 39/100
# 27/27 - 0s - loss: 0.0018 - 32ms/epoch - 1ms/step
# Epoch 40/100
# 27/27 - 0s - loss: 0.0017 - 31ms/epoch - 1ms/step
# Epoch 41/100
# 27/27 - 0s - loss: 0.0017 - 32ms/epoch - 1ms/step
# Epoch 42/100
# 27/27 - 0s - loss: 0.0017 - 32ms/epoch - 1ms/step
# Epoch 43/100
# 27/27 - 0s - loss: 0.0017 - 32ms/epoch - 1ms/step
# Epoch 44/100
# 27/27 - 0s - loss: 0.0018 - 32ms/epoch - 1ms/step
# Epoch 45/100
# 27/27 - 0s - loss: 0.0017 - 32ms/epoch - 1ms/step
# Epoch 46/100
# 27/27 - 0s - loss: 0.0017 - 32ms/epoch - 1ms/step
# Epoch 47/100
# 27/27 - 0s - loss: 0.0017 - 34ms/epoch - 1ms/step
# Epoch 48/100
# 27/27 - 0s - loss: 0.0017 - 35ms/epoch - 1ms/step
# Epoch 49/100
# 27/27 - 0s - loss: 0.0017 - 34ms/epoch - 1ms/step
# Epoch 50/100
# 27/27 - 0s - loss: 0.0017 - 34ms/epoch - 1ms/step
# Epoch 51/100
# 27/27 - 0s - loss: 0.0017 - 33ms/epoch - 1ms/step
# Epoch 52/100
# 27/27 - 0s - loss: 0.0017 - 32ms/epoch - 1ms/step
# Epoch 53/100
# 27/27 - 0s - loss: 0.0017 - 32ms/epoch - 1ms/step
# Epoch 54/100
# 27/27 - 0s - loss: 0.0017 - 32ms/epoch - 1ms/step
# Epoch 55/100
# 27/27 - 0s - loss: 0.0017 - 32ms/epoch - 1ms/step
# Epoch 56/100
# 27/27 - 0s - loss: 0.0016 - 51ms/epoch - 2ms/step
# Epoch 57/100
# 27/27 - 0s - loss: 0.0016 - 44ms/epoch - 2ms/step
# Epoch 58/100
# 27/27 - 0s - loss: 0.0016 - 37ms/epoch - 1ms/step
# Epoch 59/100
# 27/27 - 0s - loss: 0.0016 - 33ms/epoch - 1ms/step
# Epoch 60/100
# 27/27 - 0s - loss: 0.0016 - 32ms/epoch - 1ms/step
# Epoch 61/100
# 27/27 - 0s - loss: 0.0016 - 32ms/epoch - 1ms/step
# Epoch 62/100
# 27/27 - 0s - loss: 0.0016 - 33ms/epoch - 1ms/step
# Epoch 63/100
# 27/27 - 0s - loss: 0.0016 - 33ms/epoch - 1ms/step
# Epoch 64/100
# 27/27 - 0s - loss: 0.0016 - 32ms/epoch - 1ms/step
# Epoch 65/100
# 27/27 - 0s - loss: 0.0016 - 31ms/epoch - 1ms/step
# Epoch 66/100
# 27/27 - 0s - loss: 0.0016 - 33ms/epoch - 1ms/step
# Epoch 67/100
# 27/27 - 0s - loss: 0.0016 - 32ms/epoch - 1ms/step
# Epoch 68/100
# 27/27 - 0s - loss: 0.0016 - 32ms/epoch - 1ms/step
# Epoch 69/100
# 27/27 - 0s - loss: 0.0016 - 32ms/epoch - 1ms/step
# Epoch 70/100
# 27/27 - 0s - loss: 0.0015 - 31ms/epoch - 1ms/step
# Epoch 71/100
# 27/27 - 0s - loss: 0.0016 - 32ms/epoch - 1ms/step
# Epoch 72/100
# 27/27 - 0s - loss: 0.0016 - 33ms/epoch - 1ms/step
# Epoch 73/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 74/100
# 27/27 - 0s - loss: 0.0015 - 33ms/epoch - 1ms/step
# Epoch 75/100
# 27/27 - 0s - loss: 0.0016 - 31ms/epoch - 1ms/step
# Epoch 76/100
# 27/27 - 0s - loss: 0.0016 - 32ms/epoch - 1ms/step
# Epoch 77/100
# 27/27 - 0s - loss: 0.0015 - 33ms/epoch - 1ms/step
# Epoch 78/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 79/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 80/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 81/100
# 27/27 - 0s - loss: 0.0015 - 33ms/epoch - 1ms/step
# Epoch 82/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 83/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 84/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 85/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 86/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 87/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 88/100
# 27/27 - 0s - loss: 0.0016 - 33ms/epoch - 1ms/step
# Epoch 89/100
# 27/27 - 0s - loss: 0.0016 - 32ms/epoch - 1ms/step
# Epoch 90/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 91/100
# 27/27 - 0s - loss: 0.0015 - 31ms/epoch - 1ms/step
# Epoch 92/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 93/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 94/100
# 27/27 - 0s - loss: 0.0015 - 31ms/epoch - 1ms/step
# Epoch 95/100
# 27/27 - 0s - loss: 0.0015 - 33ms/epoch - 1ms/step
# Epoch 96/100
# 27/27 - 0s - loss: 0.0015 - 31ms/epoch - 1ms/step
# Epoch 97/100
# 27/27 - 0s - loss: 0.0015 - 32ms/epoch - 1ms/step
# Epoch 98/100
# 27/27 - 0s - loss: 0.0015 - 33ms/epoch - 1ms/step
# Epoch 99/100
# 27/27 - 0s - loss: 0.0015 - 33ms/epoch - 1ms/step
# Epoch 100/100
# 27/27 - 0s - loss: 0.0015 - 33ms/epoch - 1ms/step
# 1/1 [==============================] - 0s 397ms/step
# 2022년의 CO2 배출량 예측값:  [[381.84262]]
